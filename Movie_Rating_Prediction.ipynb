# %%
#Importing Important Libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
# Making accessible to google drive

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading the dataset

df = pd.read_csv('/content/drive/My Drive/Movies - Sheet1.csv')

# %%
df.head()
# Out:
#    MoviesID                       MoviesName     \
# 0         2                      Jumanji (1995)
# 1         3             Grumpier Old Men (1995)
# 2         4            Waiting to Exhale (1995)
# 3         5  Father of the Bride Part II (1995)
# 4         6                         Heat (1995)
#
#   Category                         ID  MovieID  Ratings  TimeStamp  UserID  \
# 0    Adventure|Children's|Fantasy   1      661        3  978302109       2
# 1                  Comedy|Romance   1      914        3  978301968       3
# 2                    Comedy|Drama   1     3408        4  978300275       4
# 3                          Comedy   1     2355        5  978824291       5
# 4           Action|Crime|Thriller   1     1197        3  978302268       6
#
#   Gender  Age                     Occupation             Zip-Code
# 0      M                      56                      16    70072
# 1      M                      25                      15    55117
# ...

# %%
# Splitting the data into predictors and target

predictors = df.iloc[:, [4,9,10]]
target = df.iloc[:, [5]]

# %%
predictors.head()
target.head()
# Out:
#    Ratings
# 0        3
# 1        3
# 2        4
# 3        5
# 4        3

# %%
# Normalizing the data

predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()

# %%
# Number of columns of Predectors
n_cols = predictors_norm.shape[1]
# Out:
# 3

# %%
# Splitting the data into train (70% of whole dataset) and test (30% of whole dataset) dataset

X_train, X_test, y_train, y_test = train_test_split( predictors_norm, target, test_size=0.2, random_state=4)

# %%
# Importing keras and related packages to create Sequential Dense model

import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Define Regression Model

def regression_model():

  # Create Model
  model = Sequential()
  model.add(Dense(10, activation = 'relu', input_shape=(n_cols,)))
  model.add(Dense(10, activation='relu'))
  model.add(Dense(10, activation='relu'))
  model.add(Dense(1))

  # Compile Model
  model.compile(optimizer='adam', loss='mean_squared_error', metrics = ['accuracy'])
  return model

# %%
# Build a model

model = regression_model()

# Fit the model

model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 12ms/step - loss: 599.8036 - accuracy: 0.0143 - val_loss: 157.1760 - val_accuracy: 0.0496
# Epoch 2/100
# 18/18 [==============================] - 0s 4ms/step - loss: 83.3747 - accuracy: 0.0250 - val_loss: 20.7303 - val_accuracy: 0.0071
# Epoch 3/100
# 18/18 [==============================] - 0s 4ms/step - loss: 20.2761 - accuracy: 0.0107 - val_loss: 11.2586 - val_accuracy: 0.0496
# Epoch 4/100
# 18/18 [==============================] - 0s 5ms/step - loss: 12.6472 - accuracy: 0.0232 - val_loss: 9.5115 - val_accuracy: 0.0496
# Epoch 5/100
# 18/18 [==============================] - 0s 5ms/step - loss: 10.1212 - accuracy: 0.0232 - val_loss: 8.7649 - val_accuracy: 0.0496
# Epoch 6/100
# 18/18 [==============================] - 0s 4ms/step - loss: 9.1477 - accuracy: 0.0250 - val_loss: 8.1794 - val_accuracy: 0.0496
# Epoch 7/100
# ...

# %%
# Evaluate Model on Test data

loss_val = model.evaluate(X_test, y_test, verbose = 0)

print('Test loss:', loss_val[0])
# Out:
# Test loss: 1.5758814811706543
